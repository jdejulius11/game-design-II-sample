# %% [markdown]
# <a href="https://colab.research.google.com/github/jdejulius11/game-design-II-sample/blob/main/DeepSolar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f581c1b8-bb71-4196-a453-39d0f0201a7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f581c1b8-bb71-4196-a453-39d0f0201a7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving deepsolar_tract.csv to deepsolar_tract (2).csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/deepsolar_tract.csv', 'r') as f:
  df = pd.read_csv('deepsolar_tract.csv', encoding='latin-1')

# %%
df
# Out:
#        Unnamed: 0  tile_count  ...  rebate  avg_electricity_retail_rate
# 0               0         0.0  ...       0                         9.46
# 1               1        25.0  ...       0                         9.46
# 2               2         3.0  ...       0                         9.46
# 3               3         0.0  ...       0                         9.46
# 4               4         5.0  ...       0                         9.46
# ...           ...         ...  ...     ...                          ...
# 72532       72533         1.0  ...       0                         9.82
# 72533       72534         0.0  ...       0                         7.86
# 72534       72535         1.0  ...       0                         7.86
# 72535       72536         0.0  ...       0                         7.86
# 72536       72537         3.0  ...       0                         8.66
#
# [72537 rows x 169 columns]

# %%
df.head(5)
# Out:
#    Unnamed: 0  tile_count  ...  rebate  avg_electricity_retail_rate
# 0           0         0.0  ...       0                         9.46
# 1           1        25.0  ...       0                         9.46
# 2           2         3.0  ...       0                         9.46
# 3           3         0.0  ...       0                         9.46
# 4           4         5.0  ...       0                         9.46
#
# [5 rows x 169 columns]

# %%
df.corr(method='pearson')
# Out:
#                              Unnamed: 0  ...  avg_electricity_retail_rate
# Unnamed: 0                     1.000000  ...                    -0.360364
# tile_count                    -0.131263  ...                     0.273223
# solar_system_count            -0.151690  ...                     0.289145
# total_panel_area              -0.062767  ...                     0.150733
# fips                           0.262989  ...                    -0.327572
# ...                                 ...  ...                          ...
# cooperate_tax                  0.092920  ...                    -0.069030
# property_tax                  -0.212012  ...                     0.553040
# sales_tax                     -0.141248  ...                     0.370512
# rebate                        -0.268311  ...                     0.659453
# avg_electricity_retail_rate   -0.360364  ...                     1.000000
#
# [166 rows x 166 columns]
